# %%
'''
https://scikit-learn.org/stable/modules/neural_networks_supervised.html#classification
https://scikit-learn.org/stable/supervised_learning.html


'''
# Out:
# '\nhttps://scikit-learn.org/stable/modules/neural_networks_supervised.html#classification\nhttps://scikit-learn.org/stable/supervised_learning.html\n\n\n'

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz/bin/'
import pandas as pd
from sklearn import tree

# %% [markdown]
# #Read data

# %%
#Read data
df_mx = pd.read_csv("Sample Data/MX.csv", index_col=0)
df_thai = pd.read_csv("Sample Data/THAI.csv", index_col=0)
df_sgp = pd.read_csv("Sample Data/SGP.csv", index_col=0)

df_agg = pd.concat([df_mx,df_sgp, df_thai])
#df_test = pd.concat([df_sgp])
df_agg.head()
# Out:
#                                                     Short-term debt (% of total external debt)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                              0.332262
# 0.719574                                                                              0.332827
# 0.723084                                                                              0.333128
# 0.716959                                                                              0.334377
# 0.711052                                                                              0.337098
#
#                                                     Real interest rate (%)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                          0.632057
# 0.719574                                                          0.628160
# 0.723084                                                          0.626119
# 0.716959                                                          0.627000
# 0.711052                                                          0.628525
#
#                                                     Total reserves minus gold (current US$)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                           0.000000
# 0.719574                                                                           0.000919
# 0.723084                                                                           0.002037
# 0.716959                                                                           0.002957
# 0.711052                                                                           0.003344
#
#                                                     Trade (% of GDP)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                    0.015947
# 0.719574                                                    0.000000
# 0.723084                                                    0.008036
# 0.716959                                                    0.022985
# 0.711052                                                    0.039716
#
#                                                     Imports of goods and services (current US$)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                               0.000023
# 0.719574                                                                               0.000000
# 0.723084                                                                               0.001064
# 0.716959                                                                               0.003367
# 0.711052                                                                               0.007784
#
#                                                     Exports of goods and services (current US$)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                               0.000000
# 0.719574                                                                               0.000463
# 0.723084                                                                               0.001709
# 0.716959                                                                               0.003645
# 0.711052                                                                               0.006346
#
#                                                     Current account balance (% of GDP)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                      0.395944
# 0.719574                                                                      0.391082
# 0.723084                                                                      0.441825
# 0.716959                                                                      0.476529
# 0.711052                                                                      0.493558
#
#                                                     Portfolio investment, net (BoP, current US$)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                                0.592416
# 0.719574                                                                                0.591677
# 0.723084                                                                                0.592286
# 0.716959                                                                                0.592927
# 0.711052                                                                                0.593702
#
#                                                     Foreign direct investment, net inflows (% of GDP)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                                     0.134691
# 0.719574                                                                                     0.108111
# 0.723084                                                                                     0.000000
# 0.716959                                                                                     0.120226
# 0.711052                                                                                     0.086807
#
#                                                     Real GDP (current US$)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                          0.074058
# 0.719574                                                          0.075680
# 0.723084                                                          0.079874
# 0.716959                                                          0.084142
# 0.711052                                                          0.089797
#
#                                                     ...  \
# Total debt service (% of exports of goods, serv...  ...
# 0.724111                                            ...
# 0.719574                                            ...
# 0.723084                                            ...
# 0.716959                                            ...
# 0.711052                                            ...
#
#                                                     Left Government (democ)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                0.0
# 0.719574                                                                0.0
# 0.723084                                                                0.0
# 0.716959                                                                0.0
# 0.711052                                                                0.0
#
#                                                     Polity (polity)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                        0.2
# 0.719574                                                        0.2
# 0.723084                                                        0.2
# 0.716959                                                        0.2
# 0.711052                                                        0.2
#
#                                                     Durable (durable)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                           40
# 0.719574                                                           41
# 0.723084                                                           42
# 0.716959                                                           43
# 0.711052                                                           44
#
#                                                     Turnover (xconst)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                            3
# 0.719574                                                            3
# 0.723084                                                            3
# 0.716959                                                            3
# 0.711052                                                            3
#
#                                                     Legislative/Executive election (exrec)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                                 3
# 0.719574                                                                                 3
# 0.723084                                                                                 3
# 0.716959                                                                                 3
# 0.711052                                                                                 3
#
#                                                     State fragility index (sfi)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                    0.4
# 0.719574                                                                    0.4
# 0.723084                                                                    0.4
# 0.716959                                                                    0.4
# 0.711052                                                                    0.4
#
#                                                     Years (poleff)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                       1.0
# 0.719574                                                       1.0
# 0.723084                                                       1.0
# 0.716959                                                       1.0
# 0.711052                                                       1.0
#
#                                                     Economic Effectiveness (ecoeff)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                                       0.25
# 0.719574                                                                       0.25
# 0.723084                                                                       0.25
# 0.716959                                                                       0.25
# 0.711052                                                                       0.25
#
#                                                     Presist (presistance)  \
# Total debt service (% of exports of goods, serv...
# 0.724111                                                               47
# 0.719574                                                               47
# 0.723084                                                               47
# 0.716959                                                               47
# 0.711052                                                               47
#
#                                                     Target
# Total debt service (% of exports of goods, serv...
# 0.724111                                                 0
# 0.719574                                                 0
# 0.723084                                                 0
# 0.716959                                                 0
# 0.711052                                                 0
#
# [5 rows x 38 columns]

# %% [markdown]
# #Explore the Data

# %% [markdown]
# #Classification with Scikit-Learn

# %%
from sklearn import svm
import numpy as np

# 讀入資料
X = df_agg.drop(columns=['Target'])
X = X.to_numpy()
y = df_agg['Target'].values
X
# Out:
# array([[3.32262010e-01, 6.32056762e-01, 0.00000000e+00, ...,
#         1.00000000e+00, 2.50000000e-01, 4.70000000e+01],
#        [3.32826525e-01, 6.28160413e-01, 9.19024000e-04, ...,
#         1.00000000e+00, 2.50000000e-01, 4.70000000e+01],
#        [3.33127599e-01, 6.26119198e-01, 2.03680600e-03, ...,
#         1.00000000e+00, 2.50000000e-01, 4.70000000e+01],
#        ...,
#        [5.84078401e-01, 2.20348487e-01, 8.71239697e-01, ...,
#         2.30000000e+00, 2.50000000e-01, 5.00000000e+00],
#        [6.82247993e-01, 3.24759596e-01, 1.00000000e+00, ...,
#         2.60000000e+00, 2.50000000e-01, 5.00000000e+00],
#        [6.38123842e-01, 9.80396310e-02, 9.31415010e-01, ...,
#         2.90000000e+00, 2.50000000e-01, 5.00000000e+00]])

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5769230769230769, 0.9, 'X[33] <= 0.384\ngini = 0.214\nsamples = 156\nvalue = [137, 19]'),
#  Text(0.3076923076923077, 0.7, 'X[18] <= 0.889\ngini = 0.091\nsamples = 126\nvalue = [120, 6]'),
#  Text(0.15384615384615385, 0.5, 'X[28] <= 0.85\ngini = 0.049\nsamples = 119\nvalue = [116, 3]'),
#  Text(0.07692307692307693, 0.3, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.23076923076923078, 0.3, 'X[12] <= 0.247\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.15384615384615385, 0.1, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3076923076923077, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.46153846153846156, 0.5, 'X[11] <= 0.569\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.38461538461538464, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5384615384615384, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8461538461538461, 0.7, 'X[20] <= 0.465\ngini = 0.491\nsamples = 30\nvalue = [17, 13]'),
#  Text(0.7692307692307693, 0.5, 'X[12] <= 0.19\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.6923076923076923, 0.3, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.8461538461538461, 0.3, 'X[34] <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7692307692307693, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9230769230769231, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9230769230769231, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]')]

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
#graph.render("CCSP")

# %%
'''
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=CCSP.feature_names,  
                     class_names=CCSP.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph 
'''
# Out:
# '\ndot_data = tree.export_graphviz(clf, out_file=None, \n                     feature_names=CCSP.feature_names,  \n                     class_names=CCSP.target_names,  \n                     filled=True, rounded=True,  \n                     special_characters=True)  \ngraph = graphviz.Source(dot_data)  \ngraph \n'

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(X, y)
r = export_text(decision_tree)
print(r)
# Out:
# |--- feature_33 <= 0.38
# |   |--- feature_15 <= 0.01
# |   |   |--- class: 0
# |   |--- feature_15 >  0.01
# |   |   |--- class: 0
# |--- feature_33 >  0.38
# |   |--- feature_20 <= 0.46
# |   |   |--- class: 0
# |   |--- feature_20 >  0.46
# |   |   |--- class: 1
