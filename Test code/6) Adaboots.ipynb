# %%
# Load libraries
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

#score
from sklearn.metrics import precision_score, accuracy_score, roc_auc_score, confusion_matrix,f1_score, roc_curve, auc, recall_score

# %%
#Read data
df_mx = pd.read_csv("Sample Data/MX.csv", index_col=0)
df_thai = pd.read_csv("Sample Data/THAI.csv", index_col=0)
df_sgp = pd.read_csv("Sample Data/SGP.csv", index_col=0)

df_agg = pd.concat([df_thai, df_mx, df_sgp])
df_test = pd.concat([df_sgp])
df_agg.head()
# Out:
#                                                     Short-term debt (% of total external debt)  \
# Total debt service (% of exports of goods, serv...
# 0.478220                                                                              0.417122
# 0.488071                                                                              0.418222
# 0.507164                                                                              0.417371
# 0.529773                                                                              0.418589
# 0.568958                                                                              0.417134
#
#                                                     Real interest rate (%)  \
# Total debt service (% of exports of goods, serv...
# 0.478220                                                          0.395807
# 0.488071                                                          0.425714
# ...

# %%
X = df_agg.drop(columns=['Target'])
y = df_agg['Target']

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8936170212765957

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# Import Support Vector Classifier
from sklearn.svm import SVC
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
svc=SVC(probability=True, kernel='linear')

# Create adaboost classifer object
abc =AdaBoostClassifier(n_estimators=50, base_estimator=svc,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.851063829787234

# %%
# 績效


print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

print("Precision Score",precision_score(y_test, y_pred, average='macro'))
print("Precision Score (Micro", precision_score(y_test, y_pred, average='micro'))
print("Precision Score (Weighted)",precision_score(y_test, y_pred, average='weighted'))
print("Precision Score", precision_score(y_test, y_pred, average=None))

print("Recall Score (Macro)", recall_score(y_test, y_pred, average='macro',zero_division=1))
print("Recall Score (Micro)", recall_score(y_test, y_pred, average='micro',zero_division=1))
print("Recall Score (Weight)",recall_score(y_test, y_pred, average='weighted',zero_division=1))
print("Recall Score (Avg None)",recall_score(y_test, y_pred, average=None,zero_division=1))


#print("Roc_Score:", roc_auc_score(y, clf.decision_function(X)))      
print("F1 Score (Macro):", f1_score(y_test, y_pred, average='macro'))
print("F1 Score (Micro):", f1_score(y_test, y_pred, average='micro'))
print("F1 Score (Weighted):", f1_score(y_test, y_pred, average='weighted'))
print("F1 Score (Avg None):", f1_score(y_test, y_pred, average=None))
print("F1 Score:", f1_score(y_test, y_pred, zero_division=1))
# Out:
# Confusion Matrix:
#  [[40  0]
#  [ 7  0]]
# Accuracy: 0.851063829787234
# Precision Score 0.425531914893617
# Precision Score (Micro 0.851063829787234
# Precision Score (Weighted) 0.724309642372114
# Precision Score [0.85106383 0.        ]
# Recall Score (Macro) 0.5
# Recall Score (Micro) 0.851063829787234
# Recall Score (Weight) 0.851063829787234
# Recall Score (Avg None) [1. 0.]
# F1 Score (Macro): 0.4597701149425288
# F1 Score (Micro): 0.8510638297872339
# F1 Score (Weighted): 0.7825874296894108
# F1 Score (Avg None): [0.91954023 0.        ]
# F1 Score: 0.0
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
